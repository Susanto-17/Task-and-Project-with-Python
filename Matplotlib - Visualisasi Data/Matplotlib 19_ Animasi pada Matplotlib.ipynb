# %% [markdown]
# # Animasi pada Matplotlib
#
# Dalam sesi ini kita akan mempelajari cara untuk membuat animasi dengan Matplotlib.

# %% [markdown]
# ## 1. Import Modules

# %%
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.4
# 1.20.1

# %% [markdown]
# ## 2. Review Figure

# %%
fig = plt.figure()
# plt.xlim(0, 4)
# plt.ylim(-2, 2)

# print(plt.plot([]))
# Out:
# <div id='e90f4c13-5dc1-4436-9890-b8009acbc851'></div>

# %%
fig = plt.figure()
plt.xlim(0, 4)
plt.ylim(-2, 2)

# print(plt.plot([]))
# Out:
# <div id='8fe49626-7cf1-441b-bb63-b88560d27a8e'></div>
# (-2.0, 2.0)

# %%
fig = plt.figure()
plt.xlim(0, 4)
plt.ylim(-2, 2)

print(plt.plot([]))
# Out:
# <div id='d5ad13ff-f7f4-4614-a3a2-48e8326e655e'></div>
# [<matplotlib.lines.Line2D object at 0x000002D3CDD921C0>]

# %% [markdown]
# ## 3. Animasi pada Matplotlib

# %%
fig = plt.figure()
plt.xlim(0, 4)
plt.ylim(-2, 2)

line = plt.plot([])[0]

def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line

anim = FuncAnimation(fig, animate, frames=200, interval=20)

video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)

plt.close()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-5fbc65ef4140> in <module>
#      13 anim = FuncAnimation(fig, animate, frames=200, interval=20)
#      14
# ---> 15 video = anim.to_html5_video()
#      16 html = display.HTML(video)
#      17 display.display(html)
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in to_html5_video(self, embed_limit)
#    1330                 # We create a writer manually so that we can get the
#    1331                 # appropriate size for the tag
# -> 1332                 Writer = writers[mpl.rcParams['animation.writer']]
#    1333                 writer = Writer(codec='h264',
#    1334                                 bitrate=mpl.rcParams['animation.bitrate'],
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in __getitem__(self, name)
#     164         if self.is_available(name):
#     165             return self._registered[name]
# --> 166         raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#     167
#     168
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available
